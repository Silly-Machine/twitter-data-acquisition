# %%
from utils import find_root
find_root()

# %%
from src import get_credentials
from src import to_pandas
from src import tools
import pandas as pd

# %%
credentials = get_credentials()
api_cnx = tools(**credentials)
#-------------------------------
raw_json = api_cnx.get_tweets()
df = to_pandas(raw_json)
#-------------------------------
df.head()
# Out:
#                        created_at                   id               id_str
# 0  Mon May 22 19:25:23 +0000 2023  1660728580123381764  1660728580123381764  \
# 1  Mon May 22 19:25:22 +0000 2023  1660728580026892292  1660728580026892292
# 2  Mon May 22 19:25:22 +0000 2023  1660728579825586178  1660728579825586178
# 3  Mon May 22 19:25:22 +0000 2023  1660728579800399872  1660728579800399872
# 4  Mon May 22 19:25:22 +0000 2023  1660728579741700101  1660728579741700101
#
#                                            full_text  truncated
# 0  Sim...pra que punir por não ter tomado água?\n...      False  \
# 1  @SuperVia_trens Olá,  boa tarde.\nTrem com des...      False
# 2                         kkkkkkkkkkkkkkkkk que ódio      False
# 3  @goleadadazoeira -&gt; São Paulo contra Liverp...      False
# 4           @clebindacpv Brt pelos acesso né filhote      False
#
#   display_text_range                                           entities
# 0            [0, 95]  {'hashtags': [], 'symbols': [], 'user_mentions...  \
# 1           [16, 82]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2            [0, 26]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3          [17, 180]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [13, 40]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata
# 0  {'iso_language_code': 'pt', 'result_type': 're...  \
# 1  {'iso_language_code': 'pt', 'result_type': 're...
# 2  {'iso_language_code': 'pt', 'result_type': 're...
# 3  {'iso_language_code': 'pt', 'result_type': 're...
# 4  {'iso_language_code': 'pt', 'result_type': 're...
#
#                                               source  in_reply_to_status_id
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN  \
# 1  <a href="http://twitter.com/download/android" ...           1.660711e+18
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="https://mobile.twitter.com" rel="nofo...           1.660722e+18
# 4  <a href="http://twitter.com/download/iphone" r...           1.660473e+18
#
#    ...   geo  coordinates place contributors is_quote_status retweet_count
# 0  ...  None         None  None         None           False             0  \
# 1  ...  None         None  None         None           False             0
# 2  ...  None         None  None         None           False             0
# 3  ...  None         None  None         None           False             0
# 4  ...  None         None  None         None           False             0
#
#   favorite_count favorited retweeted  lang
# 0              0     False     False    pt
# 1              0     False     False    pt
# 2              0     False     False    pt
# 3              0     False     False    pt
# 4              0     False     False    pt
#
# [5 rows x 25 columns]
