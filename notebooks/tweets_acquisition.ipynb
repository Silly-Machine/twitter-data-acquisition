# %%
if 'init_executed' not in globals():
    # %run __init__.py
    init_executed = True
# -------------------------------
from src import get_credentials
from src import to_pandas
from src import tools
import pandas as pd

# %%
credentials = get_credentials()
api_cnx = tools(**credentials)
#-------------------------------
raw_json = api_cnx.get_tweets()
df = to_pandas(raw_json)
#-------------------------------
df.head()
# Out:
#                        created_at                   id               id_str
# 0  Mon May 22 20:13:30 +0000 2023  1660740692736372736  1660740692736372736  \
# 1  Mon May 22 20:13:30 +0000 2023  1660740692539330577  1660740692539330577
# 2  Mon May 22 20:13:30 +0000 2023  1660740692476416010  1660740692476416010
# 3  Mon May 22 20:13:30 +0000 2023  1660740692468027405  1660740692468027405
# 4  Mon May 22 20:13:30 +0000 2023  1660740692199591946  1660740692199591946
#
#                                            full_text  truncated
# 0  @Marcelo_Maspfc @thamariotti ia ser legal uma ...      False  \
# 1  @simpraisa @amcpimpsh Passa longe ,nunca vi ti...      False
# 2                                    a moss me deixa      False
# 3                      @matycannot Tu és mt estranho      False
# 4  💥Matilda será nominada directa la próxima gala...      False
#
#   display_text_range                                           entities
# ...
