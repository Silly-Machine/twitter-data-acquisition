# %%
from utils import find_root
find_root()

# %%
from src.dataEngineering import to_pandas
from src.twitterTool import tools
from src.getConfig import get_credentials
import pandas as pd

# %%
credentials = get_credentials()
api_cnx = tools(**credentials)
#-------------------------------
raw_json = api_cnx.get_tweets()
df = to_pandas(raw_json)
#-------------------------------
df.head()
# Out:
#                        created_at                   id               id_str
# 0  Tue May 16 17:50:58 +0000 2023  1658530496190578688  1658530496190578688  \
# 1  Tue May 16 17:50:58 +0000 2023  1658530496001765376  1658530496001765376
# 2  Tue May 16 17:50:58 +0000 2023  1658530496001761288  1658530496001761288
# 3  Tue May 16 17:50:58 +0000 2023  1658530495951429651  1658530495951429651
# 4  Tue May 16 17:50:58 +0000 2023  1658530495729131534  1658530495729131534
#
#                                            full_text  truncated
# 0  @rickofera @SportsCenterBR E perdeu de propósito?      False  \
# 1  Vai chegando essas horas e dá uma preguiça de ...      False
# 2           @Atletico vendo roxo e vermelho superior      False
# 3  @nottdave06 Tive que compartilhar esta linda c...      False
# 4  Consegui tirar o dedo do lugar colocando um ca...      False
#
#   display_text_range                                           entities
# 0           [27, 49]  {'hashtags': [], 'symbols': [], 'user_mentions...  \
# 1            [0, 56]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [10, 40]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [12, 83]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4            [0, 52]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata
# 0  {'iso_language_code': 'pt', 'result_type': 're...  \
# 1  {'iso_language_code': 'pt', 'result_type': 're...
# 2  {'iso_language_code': 'pt', 'result_type': 're...
# 3  {'iso_language_code': 'pt', 'result_type': 're...
# 4  {'iso_language_code': 'pt', 'result_type': 're...
#
#                                               source  in_reply_to_status_id
# 0  <a href="http://twitter.com/download/iphone" r...           1.658441e+18  \
# 1  <a href="http://twitter.com/download/android" ...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...           1.658526e+18
# 3  <a href="http://twitter.com/download/android" ...           1.658508e+18
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ... is_quote_status  retweet_count favorite_count favorited retweeted lang
# 0  ...           False              0              0     False     False   pt  \
# 1  ...           False              0              0     False     False   pt
# 2  ...           False              0              0     False     False   pt
# 3  ...           False              0              0     False     False   pt
# 4  ...           False              0              0     False     False   pt
#
#   quoted_status_id quoted_status_id_str quoted_status  possibly_sensitive
# 0              NaN                  NaN           NaN                 NaN
# 1              NaN                  NaN           NaN                 NaN
# 2              NaN                  NaN           NaN                 NaN
# 3              NaN                  NaN           NaN                 NaN
# 4              NaN                  NaN           NaN                 NaN
#
# [5 rows x 29 columns]
